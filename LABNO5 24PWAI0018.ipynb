# %%
attempts = 5

for attempt in range(1, attempts + 1):
    password = input(f"Enter your password: ")

    length_ok = len(password) >= 8
    has_digit = any(char.isdigit() for char in password)
    has_upper = any(char.isupper() for char in password)

    score = length_ok + has_digit + has_upper

    if score == 0:
        strength = "Very Weak"
    elif score == 1:
        strength = "Weak"
    elif score == 2:
        strength = "Moderate"
    else:
        strength = "Strong"

    print(f"Password Strength: {strength}")

    if strength == "Strong":
        print(f"You created a strong password!")
        print(f"AI Training Level: Beginner → Intermediate")
        break

    print(f"Remaining Attempts: {attempts - attempt}")

if strength != "Strong":
    print(f"Final Result: Password is not strong enough.")
# Out:
# Enter your password:  nimrazia
# Password Strength: Weak
# Remaining Attempts: 4
# Enter your password:  nim@R_90ZIA
# Password Strength: Strong
# You created a strong password!
# AI Training Level: Beginner → Intermediate
